# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
df = pd.read_csv('Online Retail Data.csv', header=0)
df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  float64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 24.7+ MB

# %%
df.describe()
# Out:
#             quantity          price    customer_id
# count  461773.000000  461773.000000  360853.000000
# mean        9.088892       4.569963   15557.611138
# std        86.366467     153.411566    1593.728741
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   14210.000000
# 50%         3.000000       2.100000   15580.000000
# 75%        10.000000       4.210000   16938.000000
# max     10200.000000   25111.090000   18287.000000

# %% [markdown]
# # Data Cleansing

# %%
df_clean = df.copy()
# membuat kolom date
df_clean['date'] = pd.to_datetime(df_clean['order_date']).dt.date.astype('datetime64[ns]')
# menghapus semua baris tanpa customer_id
df_clean = df_clean[~df_clean['customer_id'].isna()]
# mengkonversi customer_id menjadi string
df_clean['customer_id'] = df_clean['customer_id'].astype(str)
# menghapus semua baris tanpa product_name
df_clean = df_clean[~df_clean['product_name'].isna()]
# membuat semua product_name berhuruf kecil
df_clean['product_name'] = df_clean['product_name'].str.lower()
# menghapus semua baris dengan product_code atau product_name test
df_clean = df_clean[(~df_clean['product_code'].str.lower().str.contains('test')) |
                    (~df_clean['product_name'].str.contains('test '))]
# menghapus baris dengan status cancelled, yaitu yang order_id-nya diawali 'C'
df_clean = df_clean[df_clean['order_id'].str[:1]!='C']
# mengubah nilai quantity yang negatif menjadi positif karena nilai negatif tersebut hanya menandakan order tersebut cancelled
df_clean['quantity'] = df_clean['quantity'].abs()
# menghapus baris dengan price bernilai negatif
df_clean = df_clean[df_clean['price']>0]
# membuat nilai amount, yaitu perkalian antara quantity dan price
df_clean['amount'] = df_clean['quantity'] * df_clean['price']
# mengganti product_name dari product_code yang memiliki beberapa product_name dengan salah satu product_name-nya yang paling sering muncul
most_freq_product_name = df_clean.groupby(['product_code','product_name'], as_index=False).agg(order_cnt=('order_id','nunique')).sort_values(['product_code','order_cnt'], ascending=[True,False])
most_freq_product_name['rank'] = most_freq_product_name.groupby('product_code')['order_cnt'].rank(method='first', ascending=False)
most_freq_product_name = most_freq_product_name[most_freq_product_name['rank']==1].drop(columns=['order_cnt','rank'])
df_clean = df_clean.merge(most_freq_product_name.rename(columns={'product_name':'most_freq_product_name'}), how='left', on='product_code')
df_clean['product_name'] = df_clean['most_freq_product_name']
df_clean = df_clean.drop(columns='most_freq_product_name')
# menghapus outlier
from scipy import stats
df_clean = df_clean[(np.abs(stats.zscore(df_clean[['quantity','amount']]))<3).all(axis=1)]
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
#        order_id product_code                       product_name  quantity  \
# 0        493414        21844                  red retrospot mug        36
# 1        493414        21533          retro spot large milk jug        12
# 2        493414        37508    new england ceramic cake server         2
# 3        493414       35001G               hand open shape gold         2
# 4        493414        21527   red retrospot traditional teapot        12
# ...         ...          ...                                ...       ...
# 350087   539988        84380  set of 3 butterfly cookie cutters         1
# 350088   539988       84849D              hot baths soap holder         1
# 350089   539988       84849B             fairy soap soap holder         1
# 350090   539988        22854        cream sweetheart egg holder         2
# 350091   539988       47559B                tea time oven glove         2
#
#                  order_date  price customer_id       date  amount
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350092 entries, 0 to 350091
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      350092 non-null  object
#  1   product_code  350092 non-null  object
#  2   product_name  350092 non-null  object
#  3   quantity      350092 non-null  int64
#  4   order_date    350092 non-null  object
#  5   price         350092 non-null  float64
#  6   customer_id   350092 non-null  object
#  7   date          350092 non-null  datetime64[ns]
#  8   amount        350092 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 24.0+ MB

# %% [markdown]
# # Prepare Data Basket

# %%
basket = pd.pivot_table(df_clean, index='order_id', columns='product_name', values='product_code', aggfunc='nunique', fill_value=0)
basket
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                             0                                  0
# 493427                             0                                  0
# 493428                             0                                  0
# 493432                             0                                  0
# 493433                             0                                  0
# ...                              ...                                ...
# 539981                             0                                  0
# 539982                             0                                  0
# 539985                             0                                  0
# 539987                             0                                  0
# 539988                             0                                  0
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# ...

# %%
basket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16272 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: int64(3842)
# memory usage: 477.1+ MB

# %% [markdown]
# # Encode DataFrame basket dengan nilai True untuk semua nilai di atas 0 dan False untuk semua nilai 0

# %%
def encode(x):
    if x==0:
        return False
    if x>0:
        return True

basket_encode = basket.applymap(encode)
basket_encode
# Out:
# C:\Users\jundi\AppData\Local\Temp\ipykernel_24736\3017338639.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_encode = basket.applymap(encode)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 539981                         False                              False
# 539982                         False                              False
# 539985                         False                              False
# ...

# %% [markdown]
# # Ambil transaksi dengan banyaknya produk unik lebih dari 1 saja

# %%
basket_filter = basket_encode[(basket_encode>0).sum(axis=1)>1]
basket_filter
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 539978                         False                              False
# 539981                         False                              False
# 539982                         False                              False
# 539985                         False                              False
# 539988                         False                              False
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# ...

# %%
basket_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15004 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3842)
# memory usage: 55.1+ MB

# %% [markdown]
# # Pengenalan suport, confidence , dan lift beserta contoh
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# # Pengenalan apriori algorithm
# Apriori algorithm merupakan salah satu algoritma yang digunakan dalam market basket analysis. Beberapa istilah yang dipakai dalam apriori algorithm:
# - k-itemset: kumpulan item/produk berisi k buah item
# - support: persentase itemset dibeli atas semua transaksi
# - minimum support: batas support minimal yang diinginkan sebagai kriteria frequent itemset (itemset yang sering dibeli)
#
# Sesuai namanya, apriori algorithm menggunakan prior knowledge atau pengetahuan sebelumnya tentang frequent itemset. Algoritma ini bersifat iteratif mulai dari itemset berisi 1 item dan seterusnya dan akan mengeliminasi itemset yang tidak frequent/sering (di bawah minimum support).

# %%
from mlxtend.frequent_patterns import apriori

#Buat list frequent itemset (kumpulan product yg sering dibeli)
frequent_itemset = apriori(basket_filter, min_support=.01, use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemset['product_cnt'] = frequent_itemset['itemsets'].apply(lambda x: len(x))
frequent_itemset
# Out:
#        support                                           itemsets  product_cnt
# 0     0.177953               (white hanging heart t-light holder)            1
# 1     0.099440                         (regency cakestand 3 tier)            1
# 2     0.096841                          (jumbo bag red retrospot)            1
# 3     0.079912                 (pack of 72 retro spot cake cases)            1
# 4     0.078512                    (assorted colour bird ornament)            1
# ...        ...                                                ...          ...
# 1189  0.010064  (lunch bag spaceboy design, lunch bag dolly gi...            2
# 1190  0.010064  (regency cakestand 3 tier, green regency teacu...            2
# 1191  0.010064                          (box of 9 pebble candles)            1
# 1192  0.010064                    (retrospot padded seat cushion)            1
# 1193  0.010064  (lunch bag  black skull., lunch bag pink retro...            4
#
# [1194 rows x 3 columns]

# %%
# Hitung nilai support, confidence dan lift dari setiap pasangan produk yg mungkin

from mlxtend.frequent_patterns import association_rules

product_association = association_rules(frequent_itemset, metric='confidence', min_threshold=.7).sort_values(['support','confidence'], ascending=[False,False]).reset_index(drop=True)
product_association
# Out:
#                                           antecedents  \
# 0                  (red hanging heart t-light holder)
# 1                    (sweetheart ceramic trinket box)
# 2                                 (toilet metal sign)
# 3                      (red retrospot sugar jam bowl)
# 4                      (painted metal pears assorted)
# ..                                                ...
# 81  (blue 3 piece mini dots cutlery set, green 3 p...
# 82  (pink 3 piece mini dots cutlery set, green 3 p...
# 83     (key fob , front  door , key fob , back door )
# 84  (poppy's playhouse livingroom, poppy's playhou...
# 85  (lunch bag  black skull., lunch bag pink retro...
#
#                              consequents  antecedent support  \
# 0   (white hanging heart t-light holder)            0.058784
# 1       (strawberry ceramic trinket box)            0.049254
# 2                  (bathroom metal sign)            0.026993
# 3         (red retrospot small milk jug)            0.023660
# ...

# %% [markdown]
# # Analysis
#
# Dari hasil tabel diatas dapat kita analysis sebagai berikut :
# - Produk Red Hanging Heart T-light Holder dibeli dalam 5.9% dari total transaksi (cek kolom antecendent support)
# - Saat pembeli sudah membeli Red Hanging Heart T-light Holder, 72% dari mereka akan membeli White Hanging Heart T-light Holder (cek kolom confidence)
# - Terdapat asosiasi yg kuat antara Red Hanging Heart T-light Holder dan White Hanging Heart T-light Holder dengan peluan kedua produk tsb dibeli bersamaan dalam 1 transaksi 4 kali lebih besar dari peluang kedua produk tersebut dibeli secara masing-masing (cek kolom lift)
# - Berdasarkan insight tersebut, produk White Hanging Heart T-light Holder dapat di tempatkan di dekat/sebelah Red Hanging Heart T-light Holder atau kedua produk tsb dapat di jual dalam bundel
